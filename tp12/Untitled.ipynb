# %%
import numpy as np
import pandas as pd

# %%
a=2

# %%
a
# Out:
# 2

# %%
a=3

# %%
a
# Out:
# 3

# %%
from UserDAO import UserDAO

# %%
dao = UserDAO('deb.db')

# %%
list(dao.find_all())
# Out:
# [User(id=1, first_name='Allis', last_name='Parren', email='aparren0@earthlink.net', gender='Female', ip_address='154.80.159.121'),
#  User(id=2, first_name='Dietrich', last_name='Leipoldt', email='dleipoldt1@storify.com', gender='Male', ip_address='72.177.98.150'),
#  User(id=3, first_name='Pierson', last_name='Slide', email='pslide2@ycombinator.com', gender='Male', ip_address='3.164.230.69'),
#  User(id=4, first_name='Hakeem', last_name='Puig', email='hpuig3@eepurl.com', gender='Male', ip_address='87.48.29.170'),
#  User(id=5, first_name='Rahel', last_name='Matusov', email='rmatusov4@rakuten.co.jp', gender='Female', ip_address='194.244.57.95'),
#  User(id=6, first_name='Schuyler', last_name='Halversen', email='shalversen5@sakura.ne.jp', gender='Genderqueer', ip_address='4.102.57.109'),
#  User(id=7, first_name='Morgen', last_name='Piggrem', email='mpiggrem6@xrea.com', gender='Male', ip_address='253.93.138.76'),
# ...

# %%
a = np.array([127, 3, 18], dtype=np.int8)
a
# Out:
# array([127,   3,  18], dtype=int8)

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20231120", periods=5)
dates
# Out:
# DatetimeIndex(['2023-11-20', '2023-11-21', '2023-11-22', '2023-11-23',
#                '2023-11-24'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(dao.find_all())
df
# Out:
#        id first_name  last_name                        email  gender  \
# 0       1      Allis     Parren       aparren0@earthlink.net  Female
# 1       2   Dietrich   Leipoldt       dleipoldt1@storify.com    Male
# 2       3    Pierson      Slide      pslide2@ycombinator.com    Male
# 3       4     Hakeem       Puig            hpuig3@eepurl.com    Male
# 4       5      Rahel    Matusov      rmatusov4@rakuten.co.jp  Female
# ..    ...        ...        ...                          ...     ...
# 995   996      Tobye     Pirnie       tpirniern@trellian.com  Female
# 996   997      Carey     Atheis       catheisro@buzzfeed.com    Male
# 997   998      Livia   Mayberry  lmayberryrp@istockphoto.com  Female
# 998   999       Tomi  Wilkerson        twilkersonrq@admin.ch  Female
# 999  1000      Alwyn    Craydon     acraydonrr@wikipedia.org    Male
#
#          ip_address
# 0    154.80.159.121
# 1     72.177.98.150
# 2      3.164.230.69
# 3      87.48.29.170
# 4     194.244.57.95
# ...

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.head()
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df.head()
# Out:
#    id first_name last_name                    email  gender      ip_address
# 0   1      Allis    Parren   aparren0@earthlink.net  Female  154.80.159.121
# 1   2   Dietrich  Leipoldt   dleipoldt1@storify.com    Male   72.177.98.150
# 2   3    Pierson     Slide  pslide2@ycombinator.com    Male    3.164.230.69
# 3   4     Hakeem      Puig        hpuig3@eepurl.com    Male    87.48.29.170
# 4   5      Rahel   Matusov  rmatusov4@rakuten.co.jp  Female   194.244.57.95

# %%
df.tail()
# Out:
#        id first_name  last_name                        email  gender  \
# 995   996      Tobye     Pirnie       tpirniern@trellian.com  Female
# 996   997      Carey     Atheis       catheisro@buzzfeed.com    Male
# 997   998      Livia   Mayberry  lmayberryrp@istockphoto.com  Female
# 998   999       Tomi  Wilkerson        twilkersonrq@admin.ch  Female
# 999  1000      Alwyn    Craydon     acraydonrr@wikipedia.org    Male
#
#          ip_address
# 995     15.44.28.55
# 996  134.185.53.142
# 997  250.165.235.37
# 998  156.74.227.238
# 999  25.233.240.179

# %%
df['last_name']
# Out:
# 0         Parren
# 1       Leipoldt
# 2          Slide
# 3           Puig
# 4        Matusov
#          ...
# 995       Pirnie
# 996       Atheis
# 997     Mayberry
# 998    Wilkerson
# 999      Craydon
# Name: last_name, Length: 1000, dtype: object

# %%
df.loc[901]
# Out:
# id                               902
# first_name                    Thorpe
# last_name                      Spier
# email         tspierp1@aboutads.info
# gender                          Male
# ip_address             87.216.10.102
# Name: 901, dtype: object

# %%
df[df['gender']=='Male']
# Out:
#        id  first_name  last_name                     email gender  \
# 1       2    Dietrich   Leipoldt    dleipoldt1@storify.com   Male
# 2       3     Pierson      Slide   pslide2@ycombinator.com   Male
# 3       4      Hakeem       Puig         hpuig3@eepurl.com   Male
# 6       7      Morgen    Piggrem        mpiggrem6@xrea.com   Male
# 7       8    Mohandas     Rutley   mrutley7@friendfeed.com   Male
# ..    ...         ...        ...                       ...    ...
# 989   990      Ansell       Gant         agantrh@goo.ne.jp   Male
# 990   991  Franciskus       Kemp             fkempri@51.la   Male
# 994   995      Weider  Farrimond   wfarrimondrm@taobao.com   Male
# 996   997       Carey     Atheis    catheisro@buzzfeed.com   Male
# 999  1000       Alwyn    Craydon  acraydonrr@wikipedia.org   Male
#
#           ip_address
# 1      72.177.98.150
# 2       3.164.230.69
# 3       87.48.29.170
# 6      253.93.138.76
# 7       62.24.103.92
# ..               ...
# ...

# %%
df[(df['gender']=='Male') & (df['email'].str.contains('.com'))]
# Out:
#       id first_name  last_name                     email gender  \
# 1      2   Dietrich   Leipoldt    dleipoldt1@storify.com   Male
# 2      3    Pierson      Slide   pslide2@ycombinator.com   Male
# 3      4     Hakeem       Puig         hpuig3@eepurl.com   Male
# 6      7     Morgen    Piggrem        mpiggrem6@xrea.com   Male
# 7      8   Mohandas     Rutley   mrutley7@friendfeed.com   Male
# ..   ...        ...        ...                       ...    ...
# 983  984    Trumann      Brise  tbriserb@hugedomains.com   Male
# 984  985       Mike   Polgreen      mpolgreenrc@cnet.com   Male
# 986  987   Herculie    Feehely      hfeehelyre@topsy.com   Male
# 994  995     Weider  Farrimond   wfarrimondrm@taobao.com   Male
# 996  997      Carey     Atheis    catheisro@buzzfeed.com   Male
#
#          ip_address
# 1     72.177.98.150
# 2      3.164.230.69
# 3      87.48.29.170
# 6     253.93.138.76
# 7      62.24.103.92
# ..              ...
# 983   183.97.124.46
# 984    40.84.27.127
# ...

# %%
df['upper_last_name'] = df['last_name'].map(lambda a : a.upper())
df
# Out:
#        id first_name  last_name                        email  gender  \
# 0       1      Allis     Parren       aparren0@earthlink.net  Female
# 1       2   Dietrich   Leipoldt       dleipoldt1@storify.com    Male
# 2       3    Pierson      Slide      pslide2@ycombinator.com    Male
# 3       4     Hakeem       Puig            hpuig3@eepurl.com    Male
# 4       5      Rahel    Matusov      rmatusov4@rakuten.co.jp  Female
# ..    ...        ...        ...                          ...     ...
# 995   996      Tobye     Pirnie       tpirniern@trellian.com  Female
# 996   997      Carey     Atheis       catheisro@buzzfeed.com    Male
# 997   998      Livia   Mayberry  lmayberryrp@istockphoto.com  Female
# 998   999       Tomi  Wilkerson        twilkersonrq@admin.ch  Female
# 999  1000      Alwyn    Craydon     acraydonrr@wikipedia.org    Male
#
#          ip_address upper_last_name
# 0    154.80.159.121          PARREN
# 1     72.177.98.150        LEIPOLDT
# ...
